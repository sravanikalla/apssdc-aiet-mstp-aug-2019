# %% [markdown]
# # markdown Introduction

# %% [markdown]
# # heading1
# ## heading2
# ### heading3
# #### heading4
# ##### heading5
# ###### heading6

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*<br/>
# <strike>striking text</strike><br/>
# `highlighting text`

# %% [markdown]
# <img src="data:image/png;base64,..." width="100px" height="100px">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%HTML
# <iframe width="640" height="360" src="https://www.youtube.com/embed/hEgO047GxaQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="640" height="360" src="https://www.youtube.com/embed/hEgO047GxaQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * R programming
# * scripting languages
#   -html
#   -xml

# %% [markdown]
# ## python programming

# %%
print("hello world")
print("APSSDC")
# Out:
# hello world
# APSSDC

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # operators

# %% [markdown]
# * arithematic operators
# * relational operators
# * assignment operators
# * logical operators
# * bit wise operators
# * identify operators
# * membership operators

# %% [markdown]
# ### arithematic operators

# %%
print(30+90)
print(90-30)
print(90*30)
print(4%2)
# Out:
# 120
# 60
# 2700
# 0

# %%
type(1)
# Out:
# int

# %% [markdown]
# ## logical statements

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ## relational operators

# %%
2==3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
20<18
# Out:
# False

# %%
20100>30
# Out:
# True

# %% [markdown]
# ## assignment operators

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a="hello"
type(a)
# Out:
# str

# %%
a=b=c=10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
a,b,c=1,2,3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b=b,a

# %%
a,b
# Out:
# (2, 1)

# %%
a=1

# %%
a = a + 1
a
# Out:
# 3

# %%
a +=1
a
# Out:
# 5

# %%
a *=10
a
# Out:
# 50

# %%
a //=3
a
# Out:
# 16

# %% [markdown]
# ## Bitwise operators

# %%
4 & 7
# Out:
# 4

# %%
7 |4
# Out:
# 7

# %%
8 << 2
# Out:
# 32

# %%
8 >> 2
# Out:
# 2

# %% [markdown]
# ### Identity operators

# %%
2 == 3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# ### Membership operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"Ap" in "apssdc"
# Out:
# False

# %%
"s" in "apssdc"
# Out:
# True

# %%
'c' in 'apssdc'
# Out:
# True

# %%
't' not in 'apssdc'
# Out:
# True
